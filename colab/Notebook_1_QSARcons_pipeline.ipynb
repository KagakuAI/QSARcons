# %% [markdown]
# <a href="https://colab.research.google.com/github/KagakuAI/QSARcons/blob/main/colab/Notebook_1_QSARcons_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Introduction to QSARcons
#
# **Purpose:**
# ``QSARcons`` is a package designed to identify the optimal consensus of Quantitative Structure–Activity Relationship (QSAR) models. It leverages various chemical descriptors and machine learning methods to combine multiple QSAR models.
#
# **Overview:**
# QSARcons offers three primary consensus search strategies:
#
# - **Random search**: explores random combinations of QSAR models of size N.
# - **Systematic search**: all models are sorted by accuracy metric on the validation set, and the top N models are selected.
# - **Genetic search**: Utilizes genetic algorithms to evolve and select the best-performing model combinations of size N.

# %%
# !pip install qsarcons
# Out:
# Requirement already satisfied: qsarcons in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from qsarcons) (5.9.5)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.12/dist-packages (from qsarcons) (2025.9.3)
# Requirement already satisfied: molfeat in /usr/local/lib/python3.12/dist-packages (from qsarcons) (0.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from qsarcons) (1.6.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (from qsarcons) (3.1.2)
# Requirement already satisfied: catboost in /usr/local/lib/python3.12/dist-packages (from qsarcons) (1.2.8)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from qsarcons) (0.36.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from qsarcons) (8.4.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost->qsarcons) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost->qsarcons) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost->qsarcons) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost->qsarcons) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost->qsarcons) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost->qsarcons) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost->qsarcons) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->qsarcons) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->qsarcons) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->qsarcons) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->qsarcons) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->qsarcons) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->qsarcons) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->qsarcons) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->qsarcons) (1.2.0)
# Requirement already satisfied: loguru in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (0.7.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (1.5.2)
# Requirement already satisfied: s3fs>=2021.9 in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (2025.3.0)
# Requirement already satisfied: gcsfs>=2021.9 in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (2025.3.0)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (2.9.0+cu126)
# Requirement already satisfied: datamol>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (0.12.5)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (4.5.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (3.15.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (18.1.0)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (2.12.3)
# Requirement already satisfied: pmapper in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (1.1.3)
# Requirement already satisfied: mordredcommunity in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (2.0.6)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from molfeat->qsarcons) (1.2.1)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->qsarcons) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->qsarcons) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest->qsarcons) (2.19.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit->qsarcons) (11.3.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->qsarcons) (3.6.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost->qsarcons) (2.27.5)
# Requirement already satisfied: selfies in /usr/local/lib/python3.12/dist-packages (from datamol>=0.8.0->molfeat->qsarcons) (2.2.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from datamol>=0.8.0->molfeat->qsarcons) (6.5.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2021.9->molfeat->qsarcons) (3.13.2)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2021.9->molfeat->qsarcons) (4.4.2)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2021.9->molfeat->qsarcons) (2.43.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2021.9->molfeat->qsarcons) (1.2.2)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2021.9->molfeat->qsarcons) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost->qsarcons) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost->qsarcons) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost->qsarcons) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->molfeat->qsarcons) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->molfeat->qsarcons) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->molfeat->qsarcons) (0.4.2)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /usr/local/lib/python3.12/dist-packages (from s3fs>=2021.9->molfeat->qsarcons) (2.26.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (0.7.1)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->molfeat->qsarcons) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost->qsarcons) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost->qsarcons) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost->qsarcons) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost->qsarcons) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost->qsarcons) (3.2.5)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost->qsarcons) (9.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->qsarcons) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->qsarcons) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->qsarcons) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->qsarcons) (2025.11.12)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.9->molfeat->qsarcons) (0.13.0)
# Requirement already satisfied: botocore<1.41.6,>=1.41.0 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.9->molfeat->qsarcons) (1.41.5)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.9->molfeat->qsarcons) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.9->molfeat->qsarcons) (6.7.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.9->molfeat->qsarcons) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2021.9->molfeat->qsarcons) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2021.9->molfeat->qsarcons) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2021.9->molfeat->qsarcons) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2021.9->molfeat->qsarcons) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2021.9->molfeat->qsarcons) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2021.9->molfeat->qsarcons) (1.22.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs>=2021.9->molfeat->qsarcons) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs>=2021.9->molfeat->qsarcons) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs>=2021.9->molfeat->qsarcons) (4.9.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13->molfeat->qsarcons) (1.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib->gcsfs>=2021.9->molfeat->qsarcons) (2.0.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs>=2021.9->molfeat->qsarcons) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs>=2021.9->molfeat->qsarcons) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs>=2021.9->molfeat->qsarcons) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs>=2021.9->molfeat->qsarcons) (1.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13->molfeat->qsarcons) (3.0.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs>=2021.9->molfeat->qsarcons) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs>=2021.9->molfeat->qsarcons) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs>=2021.9->molfeat->qsarcons) (1.26.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs>=2021.9->molfeat->qsarcons) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2021.9->molfeat->qsarcons) (3.3.1)

# %%
import os
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

from qsarcons.lazy import LazyML
from qsarcons.consensus import RandomSearch, SystematicSearch, GeneticSearch

# %% [markdown]
# ### 1. Load data

# %%
data_train = pd.read_csv(f"https://raw.githubusercontent.com/molecularinformatics/Computational-ADME/main/MPNN/ADME_rPPB_train.csv")
data_test = pd.read_csv(f"https://raw.githubusercontent.com/molecularinformatics/Computational-ADME/main/MPNN/ADME_rPPB_test.csv")
data_train
# Out:
#                                                 smiles  activity
# 0    Cc1cnc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)...  0.350248
# 1    CC(C)[C@@](C)(O)[C@@H]1CN(c2nc(-c3[nH]nc4ncccc...  0.622421
# 2    CC(C)(C)NC(=O)NCCN1CCC(CNC(=O)c2cc(Cl)cc(Cl)c2)C1  1.144574
# 3                     Cc1ccc(OCC(O)C(C)NC(C)C)c2c1CCC2  1.334253
# 4                  O=C(Nc1cccnc1)c1ccnc(NC(=O)C2CC2)c1  1.615287
# ..                                                 ...       ...
# 703  Cc1ccc(S(=O)(=O)Nc2c(C(=O)NC(C)C(C)(C)C)c(C)nn...  0.659916
# 704  CN(C)C(=O)C1(Cc2ccccc2-c2ccccc2)CCN(C(=O)c2cnn...  1.146841
# 705  Cc1ccc(S(=O)(=O)Nc2c(C(=O)NCC(C)(C)C)c(C)nn2-c...  0.525045
# 706                      CC(C)NCC(O)COc1cccc2[nH]ccc12  1.767527
# 707  CC#CC(=O)N1CC[C@@H](n2c(=O)n(-c3ccc(Oc4ccccc4)...  0.669596
#
# [708 rows x 2 columns]

# %%
# Get the train and test data-loaders
data_train, data_val = train_test_split(data_train, test_size=0.2, random_state=42)

# %% [markdown]
# ### 2. Build multiple 2D models

# %% [markdown]
# **For the demonstrational proposal, hyperparameter optimization (``hopt=False``) was disabled to speed up the pipeline. But it is recommended to activate it with more computational resources available**

# %%
output_folder = "adme_bench"
lazy_ml = LazyML(task="regression", hopt=False, output_folder=output_folder, verbose=True)
lazy_ml.run(data_train, data_val, data_test)
# Out:
# [1/133] Running model: avalon|RidgeRegression
#   ↳ Finished in 0.02 min | Memory usage: 0.780 GB
# [2/133] Running model: avalon|PLSRegression
#   ↳ Finished in 0.02 min | Memory usage: 0.780 GB
# [3/133] Running model: avalon|LinearSVR
#   ↳ Finished in 0.09 min | Memory usage: 0.780 GB
# [4/133] Running model: avalon|MLPRegressor
#   ↳ Finished in 0.25 min | Memory usage: 0.780 GB
# [5/133] Running model: avalon|RandomForestRegressor
#   ↳ Finished in 0.17 min | Memory usage: 0.780 GB
# [6/133] Running model: avalon|XGBRegressor
#   ↳ Finished in 0.03 min | Memory usage: 0.780 GB
# [7/133] Running model: avalon|CatBoostRegressor
#   ↳ Finished in 0.92 min | Memory usage: 0.781 GB
# [8/133] Running model: rdkit|RidgeRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.818 GB
# [9/133] Running model: rdkit|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.799 GB
# [10/133] Running model: rdkit|LinearSVR
#   ↳ Finished in 0.08 min | Memory usage: 0.799 GB
# [11/133] Running model: rdkit|MLPRegressor
#   ↳ Finished in 0.25 min | Memory usage: 0.799 GB
# [12/133] Running model: rdkit|RandomForestRegressor
#   ↳ Finished in 0.74 min | Memory usage: 0.799 GB
# [13/133] Running model: rdkit|XGBRegressor
#   ↳ Finished in 0.07 min | Memory usage: 0.799 GB
# [14/133] Running model: rdkit|CatBoostRegressor
#   ↳ Finished in 3.87 min | Memory usage: 0.799 GB
# [15/133] Running model: maccs|RidgeRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.793 GB
# [16/133] Running model: maccs|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.794 GB
# [17/133] Running model: maccs|LinearSVR
#   ↳ Finished in 0.01 min | Memory usage: 0.794 GB
# [18/133] Running model: maccs|MLPRegressor
#   ↳ Finished in 0.05 min | Memory usage: 0.794 GB
# [19/133] Running model: maccs|RandomForestRegressor
#   ↳ Finished in 0.05 min | Memory usage: 0.794 GB
# [20/133] Running model: maccs|XGBRegressor
#   ↳ Finished in 0.03 min | Memory usage: 0.794 GB
# [21/133] Running model: maccs|CatBoostRegressor
#   ↳ Finished in 0.25 min | Memory usage: 0.794 GB
# [22/133] Running model: atompair-count|RidgeRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.824 GB
# [23/133] Running model: atompair-count|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.824 GB
# [24/133] Running model: atompair-count|LinearSVR
#   ↳ Finished in 0.02 min | Memory usage: 0.824 GB
# [25/133] Running model: atompair-count|MLPRegressor
#   ↳ Finished in 0.12 min | Memory usage: 0.824 GB
# [26/133] Running model: atompair-count|RandomForestRegressor
#   ↳ Finished in 0.44 min | Memory usage: 0.824 GB
# [27/133] Running model: atompair-count|XGBRegressor
#   ↳ Finished in 0.04 min | Memory usage: 0.824 GB
# [28/133] Running model: atompair-count|CatBoostRegressor
#   ↳ Finished in 0.83 min | Memory usage: 0.824 GB
# [29/133] Running model: fcfp|RidgeRegression
#   ↳ Finished in 0.02 min | Memory usage: 0.838 GB
# [30/133] Running model: fcfp|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.838 GB
# [31/133] Running model: fcfp|LinearSVR
#   ↳ Finished in 0.01 min | Memory usage: 0.838 GB
# [32/133] Running model: fcfp|MLPRegressor
#   ↳ Finished in 0.08 min | Memory usage: 0.838 GB
# [33/133] Running model: fcfp|RandomForestRegressor
#   ↳ Finished in 0.33 min | Memory usage: 0.838 GB
# [34/133] Running model: fcfp|XGBRegressor
#   ↳ Finished in 0.03 min | Memory usage: 0.838 GB
# [35/133] Running model: fcfp|CatBoostRegressor
#   ↳ Finished in 0.44 min | Memory usage: 0.838 GB
# [36/133] Running model: fcfp-count|RidgeRegression
#   ↳ Finished in 0.02 min | Memory usage: 0.820 GB
# [37/133] Running model: fcfp-count|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.820 GB
# [38/133] Running model: fcfp-count|LinearSVR
#   ↳ Finished in 0.02 min | Memory usage: 0.820 GB
# [39/133] Running model: fcfp-count|MLPRegressor
#   ↳ Finished in 0.10 min | Memory usage: 0.820 GB
# [40/133] Running model: fcfp-count|RandomForestRegressor
#   ↳ Finished in 0.28 min | Memory usage: 0.820 GB
# [41/133] Running model: fcfp-count|XGBRegressor
#   ↳ Finished in 0.03 min | Memory usage: 0.820 GB
# [42/133] Running model: fcfp-count|CatBoostRegressor
#   ↳ Finished in 0.36 min | Memory usage: 0.820 GB
# [43/133] Running model: ecfp|RidgeRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.841 GB
# [44/133] Running model: ecfp|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.841 GB
# [45/133] Running model: ecfp|LinearSVR
#   ↳ Finished in 0.01 min | Memory usage: 0.841 GB
# [46/133] Running model: ecfp|MLPRegressor
#   ↳ Finished in 0.12 min | Memory usage: 0.841 GB
# [47/133] Running model: ecfp|RandomForestRegressor
#   ↳ Finished in 0.31 min | Memory usage: 0.841 GB
# [48/133] Running model: ecfp|XGBRegressor
#   ↳ Finished in 0.03 min | Memory usage: 0.841 GB
# [49/133] Running model: ecfp|CatBoostRegressor
#   ↳ Finished in 0.47 min | Memory usage: 0.841 GB
# [50/133] Running model: ecfp-count|RidgeRegression
#   ↳ Finished in 0.03 min | Memory usage: 0.850 GB
# [51/133] Running model: ecfp-count|PLSRegression
#   ↳ Finished in 0.02 min | Memory usage: 0.850 GB
# [52/133] Running model: ecfp-count|LinearSVR
#   ↳ Finished in 0.02 min | Memory usage: 0.850 GB
# [53/133] Running model: ecfp-count|MLPRegressor
#   ↳ Finished in 0.14 min | Memory usage: 0.850 GB
# [54/133] Running model: ecfp-count|RandomForestRegressor
#   ↳ Finished in 0.27 min | Memory usage: 0.850 GB
# [55/133] Running model: ecfp-count|XGBRegressor
#   ↳ Finished in 0.03 min | Memory usage: 0.850 GB
# [56/133] Running model: ecfp-count|CatBoostRegressor
#   ↳ Finished in 0.37 min | Memory usage: 0.850 GB
# [57/133] Running model: topological|RidgeRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.850 GB
# [58/133] Running model: topological|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.850 GB
# [59/133] Running model: topological|LinearSVR
#   ↳ Finished in 0.01 min | Memory usage: 0.850 GB
# [60/133] Running model: topological|MLPRegressor
#   ↳ Finished in 0.12 min | Memory usage: 0.851 GB
# [61/133] Running model: topological|RandomForestRegressor
#   ↳ Finished in 0.21 min | Memory usage: 0.851 GB
# [62/133] Running model: topological|XGBRegressor
#   ↳ Finished in 0.03 min | Memory usage: 0.851 GB
# [63/133] Running model: topological|CatBoostRegressor
#   ↳ Finished in 0.36 min | Memory usage: 0.851 GB
# [64/133] Running model: topological-count|RidgeRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.822 GB
# [65/133] Running model: topological-count|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.822 GB
# [66/133] Running model: topological-count|LinearSVR
#   ↳ Finished in 0.01 min | Memory usage: 0.822 GB
# [67/133] Running model: topological-count|MLPRegressor
#   ↳ Finished in 0.17 min | Memory usage: 0.822 GB
# [68/133] Running model: topological-count|RandomForestRegressor
#   ↳ Finished in 0.21 min | Memory usage: 0.822 GB
# [69/133] Running model: topological-count|XGBRegressor
#   ↳ Finished in 0.03 min | Memory usage: 0.822 GB
# [70/133] Running model: topological-count|CatBoostRegressor
#   ↳ Finished in 0.26 min | Memory usage: 0.822 GB
# [71/133] Running model: secfp|RidgeRegression
#   ↳ Finished in 0.02 min | Memory usage: 0.845 GB
# [72/133] Running model: secfp|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.845 GB
# [73/133] Running model: secfp|LinearSVR
#   ↳ Finished in 0.02 min | Memory usage: 0.845 GB
# [74/133] Running model: secfp|MLPRegressor
#   ↳ Finished in 0.07 min | Memory usage: 0.845 GB
# [75/133] Running model: secfp|RandomForestRegressor
#   ↳ Finished in 0.38 min | Memory usage: 0.846 GB
# [76/133] Running model: secfp|XGBRegressor
#   ↳ Finished in 0.03 min | Memory usage: 0.846 GB
# [77/133] Running model: secfp|CatBoostRegressor
#   ↳ Finished in 0.39 min | Memory usage: 0.846 GB
# [78/133] Running model: scaffoldkeys|RidgeRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.813 GB
# [79/133] Running model: scaffoldkeys|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.813 GB
# [80/133] Running model: scaffoldkeys|LinearSVR
#   ↳ Finished in 0.01 min | Memory usage: 0.813 GB
# [81/133] Running model: scaffoldkeys|MLPRegressor
#   ↳ Finished in 0.04 min | Memory usage: 0.813 GB
# [82/133] Running model: scaffoldkeys|RandomForestRegressor
#   ↳ Finished in 0.04 min | Memory usage: 0.813 GB
# [83/133] Running model: scaffoldkeys|XGBRegressor
#   ↳ Finished in 0.01 min | Memory usage: 0.813 GB
# [84/133] Running model: scaffoldkeys|CatBoostRegressor
#   ↳ Finished in 0.04 min | Memory usage: 0.813 GB
# [85/133] Running model: desc2D|RidgeRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.817 GB
# [86/133] Running model: desc2D|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.817 GB
# [87/133] Running model: desc2D|LinearSVR
#   ↳ Finished in 0.01 min | Memory usage: 0.817 GB
# [88/133] Running model: desc2D|MLPRegressor
#   ↳ Finished in 0.11 min | Memory usage: 0.817 GB
# [89/133] Running model: desc2D|RandomForestRegressor
#   ↳ Finished in 0.34 min | Memory usage: 0.817 GB
# [90/133] Running model: desc2D|XGBRegressor
#   ↳ Finished in 0.11 min | Memory usage: 0.818 GB
# [91/133] Running model: desc2D|CatBoostRegressor
#   ↳ Finished in 0.84 min | Memory usage: 0.818 GB
# [92/133] Running model: estate|RidgeRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.818 GB
# [93/133] Running model: estate|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.818 GB
# [94/133] Running model: estate|LinearSVR
#   ↳ Finished in 0.01 min | Memory usage: 0.818 GB
# [95/133] Running model: estate|MLPRegressor
#   ↳ Finished in 0.04 min | Memory usage: 0.818 GB
# [96/133] Running model: estate|RandomForestRegressor
#   ↳ Finished in 0.03 min | Memory usage: 0.818 GB
# [97/133] Running model: estate|XGBRegressor
#   ↳ Finished in 0.02 min | Memory usage: 0.818 GB
# [98/133] Running model: estate|CatBoostRegressor
#   ↳ Finished in 0.03 min | Memory usage: 0.818 GB
# [99/133] Running model: erg|RidgeRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.820 GB
# [100/133] Running model: erg|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.820 GB
# [101/133] Running model: erg|LinearSVR
#   ↳ Finished in 0.01 min | Memory usage: 0.820 GB
# [102/133] Running model: erg|MLPRegressor
#   ↳ Finished in 0.07 min | Memory usage: 0.820 GB
# [103/133] Running model: erg|RandomForestRegressor
#   ↳ Finished in 0.13 min | Memory usage: 0.820 GB
# [104/133] Running model: erg|XGBRegressor
#   ↳ Finished in 0.02 min | Memory usage: 0.820 GB
# [105/133] Running model: erg|CatBoostRegressor
#   ↳ Finished in 0.30 min | Memory usage: 0.820 GB
# [106/133] Running model: cats2d|RidgeRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.820 GB
# [107/133] Running model: cats2d|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.820 GB
# [108/133] Running model: cats2d|LinearSVR
#   ↳ Finished in 0.01 min | Memory usage: 0.820 GB
# [109/133] Running model: cats2d|MLPRegressor
#   ↳ Finished in 0.05 min | Memory usage: 0.820 GB
# [110/133] Running model: cats2d|RandomForestRegressor
#   ↳ Finished in 0.09 min | Memory usage: 0.820 GB
# [111/133] Running model: cats2d|XGBRegressor
#   ↳ Finished in 0.02 min | Memory usage: 0.820 GB
# [112/133] Running model: cats2d|CatBoostRegressor
#   ↳ Finished in 0.10 min | Memory usage: 0.821 GB
# [113/133] Running model: pharm2D-cats|RidgeRegression
#   ↳ Finished in 0.02 min | Memory usage: 0.843 GB
# [114/133] Running model: pharm2D-cats|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.843 GB
# [115/133] Running model: pharm2D-cats|LinearSVR
#   ↳ Finished in 0.01 min | Memory usage: 0.834 GB
# [116/133] Running model: pharm2D-cats|MLPRegressor
#   ↳ Finished in 0.35 min | Memory usage: 0.834 GB
# [117/133] Running model: pharm2D-cats|RandomForestRegressor
#   ↳ Finished in 0.13 min | Memory usage: 0.834 GB
# [118/133] Running model: pharm2D-cats|XGBRegressor
#   ↳ Finished in 0.04 min | Memory usage: 0.834 GB
# [119/133] Running model: pharm2D-cats|CatBoostRegressor
#   ↳ Finished in 0.14 min | Memory usage: 0.834 GB
# [120/133] Running model: pharm2D-gobbi|RidgeRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.848 GB
# [121/133] Running model: pharm2D-gobbi|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.848 GB
# [122/133] Running model: pharm2D-gobbi|LinearSVR
#   ↳ Finished in 0.04 min | Memory usage: 0.848 GB
# [123/133] Running model: pharm2D-gobbi|MLPRegressor
#   ↳ Finished in 0.19 min | Memory usage: 0.857 GB
# [124/133] Running model: pharm2D-gobbi|RandomForestRegressor
#   ↳ Finished in 0.56 min | Memory usage: 0.857 GB
# [125/133] Running model: pharm2D-gobbi|XGBRegressor
#   ↳ Finished in 0.05 min | Memory usage: 0.857 GB
# [126/133] Running model: pharm2D-gobbi|CatBoostRegressor
#   ↳ Finished in 3.69 min | Memory usage: 0.858 GB
# [127/133] Running model: pharm2D-pmapper|RidgeRegression
#   ↳ Finished in 0.02 min | Memory usage: 0.858 GB
# [128/133] Running model: pharm2D-pmapper|PLSRegression
#   ↳ Finished in 0.01 min | Memory usage: 0.858 GB
# [129/133] Running model: pharm2D-pmapper|LinearSVR
#   ↳ Finished in 0.03 min | Memory usage: 0.849 GB
# [130/133] Running model: pharm2D-pmapper|MLPRegressor
#   ↳ Finished in 0.10 min | Memory usage: 0.849 GB
# [131/133] Running model: pharm2D-pmapper|RandomForestRegressor
#   ↳ Finished in 0.39 min | Memory usage: 0.849 GB
# [132/133] Running model: pharm2D-pmapper|XGBRegressor
#   ↳ Finished in 0.04 min | Memory usage: 0.849 GB
# [133/133] Running model: pharm2D-pmapper|CatBoostRegressor
#   ↳ Finished in 2.69 min | Memory usage: 0.849 GB

# %% [markdown]
# ### 3. Build model consensus

# %%
metric = "auto"
cons_size = "auto"

# %%
cons_methods = [
    ("Best", SystematicSearch(cons_size=1, metric=metric)),
    ("Random", RandomSearch(cons_size=cons_size, n_iter=1000, metric=metric)),
    ("Systematic", SystematicSearch(cons_size=cons_size, metric=metric)),
    ("Genetic", GeneticSearch(cons_size=cons_size, n_iter=50, pop_size=50, mut_prob=0.2, metric=metric))
]

# %%
# load model predictions
df_val = pd.read_csv(f"{output_folder}/val.csv")
df_test = pd.read_csv(f"{output_folder}/test.csv")

# skip first two columns (smiles and true property value)
x_val, true_val = df_val.iloc[:, 2:], df_val.iloc[:, 1]
x_test = df_test.iloc[:, 2:]

# %%
for name, cons_searcher in cons_methods:

    # run search
    best_cons = cons_searcher.run(x_val, true_val)
    print(name)
    print(best_cons)

    # make val and test predictions
    pred_val = cons_searcher.predict_cons(x_val[best_cons])
    pred_test = cons_searcher.predict_cons(x_test[best_cons])

    # write prediction accuracy metric
    df_val[name] = pred_val
    df_test[name] = pred_test
# Out:
# Best
# Index(['desc2D|CatBoostRegressor'], dtype='object')
# Random
# ['maccs|CatBoostRegressor', 'secfp|RidgeRegression', 'topological|PLSRegression', 'desc2D|CatBoostRegressor']
# Systematic
# ['desc2D|CatBoostRegressor', 'desc2D|RandomForestRegressor', 'desc2D|RidgeRegression', 'maccs|CatBoostRegressor']
# Genetic
# ['maccs|CatBoostRegressor', 'desc2D|CatBoostRegressor', 'desc2D|LinearSVR']

# %% [markdown]
# ### 4. Summurize results

# %% [markdown]
# Validation set performance

# %%
res = pd.DataFrame()
for model in df_val.columns[2:]:
    res.loc[model, "R2"] = r2_score(df_val["Y_TRUE"], df_val[model])
res.sort_values(by="R2", ascending=False)
# Out:
#                                 R2
# Genetic                   0.542244
# Systematic                0.536236
# Best                      0.525959
# desc2D|CatBoostRegressor  0.525959
# Random                    0.504566
# ...                            ...
# pharm2D-gobbi|LinearSVR  -0.481040
# atompair-count|LinearSVR -0.505303
# topological|LinearSVR    -0.716816
# avalon|RidgeRegression   -0.928701
# avalon|LinearSVR         -2.490131
#
# [137 rows x 1 columns]

# %% [markdown]
# Test set performance

# %%
res = pd.DataFrame()
for model in df_test.columns[2:]:
    res.loc[model, "R2"] = r2_score(df_test["Y_TRUE"], df_test[model])
res.sort_values(by="R2", ascending=False)
# Out:
#                                  R2
# Best                       0.549745
# desc2D|CatBoostRegressor   0.549745
# Genetic                    0.537987
# Systematic                 0.536988
# desc2D|RidgeRegression     0.502346
# ...                             ...
# pharm2D-gobbi|LinearSVR   -0.225169
# topological|LinearSVR     -0.256672
# pharm2D-pmapper|LinearSVR -0.278695
# avalon|RidgeRegression    -0.643586
# avalon|LinearSVR          -1.170516
#
# [137 rows x 1 columns]
